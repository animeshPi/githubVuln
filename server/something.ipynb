# %%
from langchain_community.llms import Ollama
from langchain.callbacks.manager import CallbackManager
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler
from langgraph.graph import END, MessageGraph
import os
import git
import json
import re




def filter_important_files(file_paths):
    important_extensions = [
    '.php'
]

    important_files = []
    for file_path in file_paths:
        if any(file_path.endswith(ext) for ext in important_extensions):
            important_files.append(file_path)
    
    return important_files


def clone_repo(repo_url, clone_dir):
    if not os.path.exists(clone_dir):
        os.makedirs(clone_dir)
    repo = git.Repo.clone_from(repo_url, clone_dir)
    return repo.working_tree_dir



def list_files(directory):
    file_list=[]
    for root, dirs, files, in os.walk(directory):
        for file in files:
            if "." in file[0]:
                continue
            else:
                file_list.append(os.path.relpath(os.path.join(root,file,), directory))
    return file_list


def save_to_file(directory, file_name, content):
    """
    Function to save content to a file in the specified directory with a specific name.
    """   
    if not os.path.exists(directory):
        os.makedirs(directory)
    file_path = os.path.join(directory, file_name)
    with open(file_path, 'a') as file:
        file.write(content)
    return file_path

def read_file(file_path):
    
    try:
        with open(file_path, 'r') as file:
            content = file.read()
            return content
    except FileNotFoundError:
        print("File not found.")
        return None
    

def add_line_numbers(input_file, output_file):
    with open(input_file, 'r') as f_in, open(output_file, 'w') as f_out:
        line_number = 1
        for line in f_in:
            f_out.write(f"{line_number}:: {line}")
            line_number += 1



    
summarizer = """ 

Task: Analyzing GitHub Repository Files for Web Vulnerabilities

Description: Your task is to meticulously analyze GitHub repository files for potential web vulnerabilities that could compromise security. Specifically, focus on identifying vulnerabilities such as SQL injection (SQLi), cross-site scripting (XSS), and other common web attack vectors. Pinpoint any code segments or patterns that pose a risk to software security.

The provided file content has file number written infront of each line in this formate 1:: 2:: 3::, you should consider it when outputing line numbers, don't provide empty line number.

Output Format:
For each identified web vulnerability, provide the following details:

Vulnerability Type: Specify the type of vulnerability found (e.g., SQL injection, XSS).
Location: Full file path and line numbers where the vulnerability is present.
Code Context: Include a few lines of code surrounding the vulnerable segment to provide context. Only include the line numbers where the vulnerability exists.
Solution: Provide a solution to mitigate the vulnerability. Modify the specific line(s) of code causing the issue, ensuring to include the full solution.
Ensure thorough analysis to accurately identify and address potential web vulnerabilities, fortifying the GitHub repository against security threats.

Output Formate only json for text and markup for code:

vulnerable_code format '''php '''
submit_code format '''php '''
the code should be in markup format
Just stick to formate no extra text here is the code or I find this or that

{
    "vulnerability_type":"vulnerability_type",
    "any_vulnerability_found":"true/false",
    "location":"full_file_path",
    "line_number":[line_number],
    "vulnerable_code":"vulnerable_code",
    "vulnerability_description":"vulnerability_description",
    "solution_code:"solution_code",
    "solution_description":"solution_description"

}


"""





directory = os.path.abspath(os.getcwd()) 
file_name = "summary.txt"
model = Ollama(model="mistral", 
             callback_manager = CallbackManager([StreamingStdOutCallbackHandler()]),
             verbose=False,
             temperature=0)

graph = MessageGraph()

graph.add_node("oracle", model)
graph.add_edge("oracle", END)

graph.set_entry_point("oracle")

runnable = graph.compile()


github_url = "https://github.com/appsecco/sqlinjection-training-app.git"
match = re.search(r"\/([^\/]+)\/?$", github_url)
clone_file_name = match.group(1).replace(".git","")
repo_path = clone_repo(github_url, clone_file_name)
files = list_files(repo_path)

print(files)

file_list = filter_important_files(files)

print(file_list)
print(len(file_list))




for files in file_list:
    
    file_path = os.path.abspath(os.getcwd())+"/"+clone_file_name+"/"+files
    print(file_path)
    
    output_file = "output.txt"
    add_line_numbers(file_path, output_file)

    file_content = read_file('output.txt')
    
    finalize = (file_content + f"file_name:{files} " + summarizer)
    result = runnable.invoke(finalize)
    string_message = str(result[1].content)
    output_message = f"""{string_message}"""

    output_directory = directory+"/"+clone_file_name+"_analysis"
    match = re.search(r"/([^/]+)$", files)

    if match:
        last_part = match.group(1)
        last_part = last_part+".txt"
        print(last_part)  # Output: secondorder_changepass.php
    else:
        print("No match found")

    save_to_file(output_directory, last_part, output_message)
# Out:
# ['LICENSE', 'Dockerfile', 'README.md', 'docker-compose.yml', 'walkthrough.md', 'www/sqlitraining.sql', 'www/secondorder_changepass.php', 'www/favicon.ico', 'www/index.php', 'www/register.php', 'www/logout.php', 'www/blindsqli.php', 'www/login2.php', 'www/login1.php', 'www/resetdb.php', 'www/db_config.php', 'www/secondorder_home.php', 'www/secondorder_register.php', 'www/robots.txt', 'www/searchproducts.php', 'www/os_sqli.php', 'www/css/htmlstyles.css', 'udf/lib_mysqludf_sys.so', 'udf/udf.hex', '.git/config', '.git/HEAD', '.git/description', '.git/index', '.git/packed-refs', '.git/objects/pack/pack-30d492ff9dd7c7cce37c90f2b099323264a20ea6.rev', '.git/objects/pack/pack-30d492ff9dd7c7cce37c90f2b099323264a20ea6.idx', '.git/objects/pack/pack-30d492ff9dd7c7cce37c90f2b099323264a20ea6.pack', '.git/info/exclude', '.git/logs/HEAD', '.git/logs/refs/heads/master', '.git/logs/refs/remotes/origin/HEAD', '.git/hooks/commit-msg.sample', '.git/hooks/pre-rebase.sample', '.git/hooks/sendemail-validate.sample', '.git/hooks/pre-commit.sample', '.git/hooks/applypatch-msg.sample', '.git/hooks/fsmonitor-watchman.sample', '.git/hooks/pre-receive.sample', '.git/hooks/prepare-commit-msg.sample', '.git/hooks/post-update.sample', '.git/hooks/pre-merge-commit.sample', '.git/hooks/pre-applypatch.sample', '.git/hooks/pre-push.sample', '.git/hooks/update.sample', '.git/hooks/push-to-checkout.sample', '.git/refs/heads/master', '.git/refs/remotes/origin/HEAD']
# ['www/secondorder_changepass.php', 'www/index.php', 'www/register.php', 'www/logout.php', 'www/blindsqli.php', 'www/login2.php', 'www/login1.php', 'www/resetdb.php', 'www/db_config.php', 'www/secondorder_home.php', 'www/secondorder_register.php', 'www/searchproducts.php', 'www/os_sqli.php']
# 13
# /Users/xeno/Desktop/Xeno/GenAI/project_vuln_finder/server/sqlinjection-training-app/www/secondorder_changepass.php
#  {
#     "vulnerability_type": "SQL Injection",
#     "any_vulnerability_found": "true",
#     "location": "www/secondorder_changepass.php:104-128",
#     "line_number": [104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127],
#     "vulnerable_code": "if (isset($_GET['debug'])) {\n          if ($_GET['debug']==\"true\")\n          {\n            $msg=\"<div style=\"border:1px solid #4CAF50; padding: 10px\">".$q."</div><br />\";\n            echo $msg;\n          }\n        }",
#     "vulnerability_description": "The code is vulnerable to SQL injection as it does not sanitize user input before using it in the query. An attacker can manipulate the 'debug' parameter to execute arbitrary SQL commands.",
#     "solution_code": "if (isset($_GET['debug'])) {\n          if ($_GET['debug']==\"true\")\n          {\n            $msg=\"<div style=\"border:1px solid #4CAF50; padding: 10px\">".htmlspecialchars($q)."</div><br />\";\n            echo $msg;\n          }\n        }",
#     "solution_description": "Sanitize user input using htmlspecialchars() function to prevent SQL injection attacks."
#   }secondorder_changepass.php.txt
# /Users/xeno/Desktop/Xeno/GenAI/project_vuln_finder/server/sqlinjection-training-app/www/index.php
#  [
#   {
#     "vulnerability_type": "SQL Injection",
#     "any_vulnerability_found": "true",
#     "location": "www/index.php",
#     "line_number": [58, 66, 69],
#     "vulnerable_code": """
#     58:           <p>Page contains code that fetches multiple entries from the DB, can be abused to extract arbitrary data</p>
#     66:             <h4><a href="blindsqli.php?user=<?php echo $_SESSION['username'];?>"  style="color:#B31D14">blindsqli.php - vulnerable to content and time based blind SQLi</a></h4>
#     69:             <h4><a href="os_sqli.php?user=<?php echo $_SESSION['username'];?>" style="color:#B31D14">os_sqli.php - can be used to interact with the filesystem and the OS via the MySQL databases</a></h4>
#     """,
#     "vulnerability_description": "The code contains SQL injection vulnerabilities in blindsqli.php, os_sqli.php, and index.php. These vulnerabilities can be exploited to extract arbitrary data or interact with the filesystem and OS via MySQL databases.",
#     "solution_code": """
#     66:             <h4><a href="blindsqli.php?user=<?php echo htmlspecialchars($_SESSION['username']);?>"  style="color:#B31D14">blindsqli.php - vulnerable to content and time based blind SQLi</a></h4>
#     69:             <h4><a href="os_sqli.php?user=<?php echo htmlspecialchars($_SESSION['username']);?>" style="color:#B31D14">os_sqli.php - can be used to interact with the filesystem and the OS via the MySQL databases</a></h4>
#     """,
#     "solution_description": "Sanitize user input using htmlspecialchars() function before outputting it in URLs."
#   },
#   {
#     "vulnerability_type": "Insecure Registration",
#     "any_vulnerability_found": "true",
#     "location": "www/secondorder_register.php",
#     "line_number": [60, 61],
#     "vulnerable_code": """
#     60:           <h4><a href="secondorder_register.php" style="color:#B31D14">secondorder_register.php - allows registration with quotes</a></h4>
#     61:           <p>Page allows user registration even with quotes. Quotes are nullified by appending a second quote to make them literals. Data is stored to backend tables without being verified if data was clean or not.</p>
#     """,
#     "vulnerability_description": "The code in secondorder_register.php allows user registration with quotes, which can lead to SQL injection and other attacks.",
#     "solution_code": """
#     61:           <p>Page allows user registration even with quotes. Quotes are nullified by appending a second quote to make them literals. Data is stored to backend tables after being verified for cleanliness.</p>
#     """,
#     "solution_description": "Validate and sanitize user input before storing it in the database."
#   },
#   {
#     "vulnerability_type": "Insecure Password Handling",
#     "any_vulnerability_found": "false",
#     "location": "www/index.php",
#     "line_number": [],
#     "vulnerable_code": "",
#     "vulnerability_description": "No insecure password handling was found in the provided code.",
#     "solution_code": "",
#     "solution_description": "Continue to follow best practices for secure password handling."
#   }
# ]index.php.txt
# /Users/xeno/Desktop/Xeno/GenAI/project_vuln_finder/server/sqlinjection-training-app/www/register.php
#  {
#     "vulnerability_type": "SQL Injection",
#     "any_vulnerability_found": "true",
#     "location": "www/register.php:98",
#     "line_number": [98],
#     "vulnerable_code": "\" . md5($pass) . \"",
#     "vulnerability_description": "The code is vulnerable to SQL injection as it concatenates user-supplied data directly into the SQL query without proper sanitization.",
#     "solution_code": "mysqli_real_escape_string($con, $pass)",
#     "solution_description": "Use mysqli_real_escape_string() function to properly escape special characters in user-supplied data before using it in the SQL query."
#   }register.php.txt
# /Users/xeno/Desktop/Xeno/GenAI/project_vuln_finder/server/sqlinjection-training-app/www/logout.php
#  {
#     "vulnerability_type": "Improper Session Handling",
#     "any_vulnerability_found": "true",
#     "location": "www/logout.php",
#     "line_number": [1, 3, 4],
#     "vulnerable_code": "```php\n1:: <?php\n2:: session_start();\n3:: session_destroy();\n4:: header('Location:index.php');\n5:: ?>\n```",
#     "vulnerability_description": "The code does not check if a session exists before destroying it, which could lead to unintended consequences.",
#     "solution_code": "```php\n1:: <?php\n2:: if(isset($_SESSION)) {\n3:: session_destroy();\n4:: }\n5:: header('Location:index.php');\n6:: ?>\n```",
#     "solution_description": "Check if a session exists before destroying it to prevent unintended consequences."
# }logout.php.txt
# /Users/xeno/Desktop/Xeno/GenAI/project_vuln_finder/server/sqlinjection-training-app/www/blindsqli.php
#  {
#     "vulnerability_type": "SQL Injection",
#     "any_vulnerability_found": "true",
#     "location": "www/blindsqli.php:90-92",
#     "line_number": [90, 91, 92],
#     "vulnerable_code": "<?php echo $row[4]; ?>",
#     "vulnerability_description": "The code is vulnerable to SQL injection as it directly uses user input (from $_GET['debug']) in the SQL query without proper sanitization.",
#     "solution_code": "<?php echo htmlspecialchars($row[4]); ?>",
#     "solution_description": "Use PHP's htmlspecialchars() function to escape special characters in the output, preventing potential SQL injection attacks."
#   }blindsqli.php.txt
# /Users/xeno/Desktop/Xeno/GenAI/project_vuln_finder/server/sqlinjection-training-app/www/login2.php
#  {
#     "vulnerability_type": "SQL Injection",
#     "any_vulnerability_found": "true",
#     "location": "www/login2.php",
#     "line_number": [80, 85],
#     "vulnerable_code": "if (!mysqli_query($con,$q)) {\n            echo 'Error: ' . mysqli_error($con);\n        }else{\n\n            $result = mysqli_query($con,$q);",
#     "vulnerability_description": "The code does not properly sanitize user input, making it susceptible to SQL injection attacks.",
#     "solution_code": "if (!$stmt = mysqli_prepare($con, $q)) {\n            echo 'Error: ' . mysqli_error($con);\n        } else if (!$stmt->bind_param($params)) {\n            echo 'Error: ' . $stmt->error;\n        } else if (!$stmt->execute()) {\n            echo 'Error: ' . $stmt->error;\n        } else if ($stmt->errno) {\n            echo 'Error: ' . $stmt->error;\n        } else {\n            $result = $stmt->get_result();\n        }\n",
#     "solution_description": "Use prepared statements with parameter binding to sanitize user input and prevent SQL injection attacks."
#   }login2.php.txt
# /Users/xeno/Desktop/Xeno/GenAI/project_vuln_finder/server/sqlinjection-training-app/www/login1.php
#  {
#     "vulnerability_type": "SQL Injection",
#     "any_vulnerability_found": "true",
#     "location": "www/login1.php:78-97",
#     "line_number": [78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 89, 90, 91, 92, 93, 94, 95, 96],
#     "vulnerable_code": "<code>\n            if (!mysqli_query($con,$q))\n            {\n                echo 'Error: ' . mysqli_error($con);\n            }\n            else{\n                \n                $result = mysqli_query($con,$q);\n                \n                // if (!$result) {\n                //    		printf("%s\n", mysqli_error($con));\n                //    		echo \"error\";\n                // }\n                \n                if (mysqli_warning_count($con)) {\n                    $e = mysqli_get_warnings($con);\n                    if ($e){\n                    do {\n                        echo \"Warning: $e->errno: $e->message\\n\";\n                    } while ($e->next()); }\n                }\n                \n                    echo \"<br /><br />\";\n                    $row = mysqli_fetch_array($result);\n                </code>",
#     "vulnerability_description": "The code is vulnerable to SQL injection as it does not sanitize user input before using it in the SQL query. An attacker can exploit this by injecting malicious SQL commands into the $q variable.",
#     "solution_code": "<code>\n            if (!mysqli_query($con,$q))\n            {\n                echo 'Error: ' . mysqli_error($con);\n            }\n            else{\n                \n                $result = mysqli_query($con, mysqli_real_escape_string($con, $q)); // Sanitize user input before using it in the SQL query.\n                \n                if (mysqli_warning_count($con)) {\n                    $e = mysqli_get_warnings($con);\n                    if ($e){\n                    do {\n                        echo \"Warning: $e->errno: $e->message\\n\";\n                    } while ($e->next()); }\n                }\n                \n                    echo \"<br /><br />\";\n                    $row = mysqli_fetch_array($result);\n                </code>",
#     "solution_description": "To mitigate the SQL injection vulnerability, sanitize user input before using it in the SQL query. In this case, use mysqli_real_escape_string() function to escape special characters in the $q variable."
#   }login1.php.txt
# /Users/xeno/Desktop/Xeno/GenAI/project_vuln_finder/server/sqlinjection-training-app/www/resetdb.php
#  {
#     "vulnerability_type": "SQL Injection",
#     "any_vulnerability_found": "true",
#     "location": "/www/resetdb.php",
#     "line_number": [5, 9, 16],
#     "vulnerable_code": '''php
# 5:: $DBUSER = 'root';
# 9:: $mysqli = new mysqli('db', $DBUSER, $DBPASS);
# 16:: if ($mysqli->multi_query($sql)) {
# ''',
#     "vulnerability_description": "The code is vulnerable to SQL injection because it does not sanitize user input before using it in the SQL query.",
#     "solution_code": '''php
# 5:: $DBUSER = 'root';
# 9:: $mysqli = new mysqli('db', $DBUSER, $DBPASS);
# 16:: if ($mysqli->multi_query(mysqli_real_escape_string($mysqli, $sql))) {
# ''',
#     "solution_description": "To mitigate the SQL injection vulnerability, use mysqli_real_escape_string() function to sanitize user input before using it in the SQL query."
#   }resetdb.php.txt
# /Users/xeno/Desktop/Xeno/GenAI/project_vuln_finder/server/sqlinjection-training-app/www/db_config.php
#  {
#     "vulnerability_type": "SQL Injection",
#     "any_vulnerability_found": "true",
#     "location": "www/db_config.php",
#     "line_number": [6, 7, 8, 9, 10, 11, 12],
#     "vulnerable_code": '''
#         6:: $DBUSER = 'root';
#         7:: $DBPASS = 'root';
#         8::
#         9:: $con=mysqli_connect('db',$DBUSER,$DBPASS,'sqlitraining');
#         10::
#         11:: // Check connection
#         12:: if (mysqli_connect_errno($con))
#     ''',
#     "vulnerability_description": "The provided code uses hardcoded user and password values, which can be a potential SQL injection vulnerability. An attacker could exploit this by manipulating the input to execute malicious SQL commands.",
#     "solution_code": '''
#         6:: $DBUSER = $_POST['username'];
#         7:: $DBPASS = $_POST['password'];
#         8:: // Always use prepared statements or parameterized queries to prevent SQL injection attacks.
#         9:: $con=mysqli_connect('db',$DBUSER,$DBPASS,'sqlitraining');
#     ''',
#     "solution_description": "Use prepared statements or parameterized queries to sanitize user input and prevent SQL injection attacks."
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 164
#     161 file_content = read_file('output.txt')
#     163 finalize = (file_content + f"file_name:{files} " + summarizer)
# --> 164 result = runnable.invoke(finalize)
#     165 string_message = str(result[1].content)
#     166 output_message = f"""{string_message}"""
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/langgraph/pregel/__init__.py:1245, in Pregel.invoke(self, input, config, stream_mode, output_keys, input_keys, interrupt_before, interrupt_after, debug, **kwargs)
#    1243 else:
#    1244     chunks = []
# -> 1245 for chunk in self.stream(
#    1246     input,
#    1247     config,
#    1248     stream_mode=stream_mode,
#    1249     output_keys=output_keys,
#    1250     input_keys=input_keys,
#    1251     interrupt_before=interrupt_before,
#    1252     interrupt_after=interrupt_after,
#    1253     debug=debug,
#    1254     **kwargs,
#    1255 ):
#    1256     if stream_mode == "values":
#    1257         latest = chunk
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/langgraph/pregel/__init__.py:827, in Pregel.stream(self, input, config, stream_mode, output_keys, input_keys, interrupt_before, interrupt_after, debug)
#     820 futures = [
#     821     executor.submit(run_with_retry, task, self.retry_policy)
#     822     for task in next_tasks
#     823 ]
#     825 # execute tasks, and wait for one to fail or all to finish.
#     826 # each task is independent from all other concurrent tasks
# --> 827 done, inflight = concurrent.futures.wait(
#     828     futures,
#     829     return_when=concurrent.futures.FIRST_EXCEPTION,
#     830     timeout=self.step_timeout,
#     831 )
#     833 # panic on failure or timeout
#     834 _panic_or_proceed(done, inflight, step)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:305, in wait(fs, timeout, return_when)
#     301         return DoneAndNotDoneFutures(done, not_done)
#     303     waiter = _create_and_install_waiters(fs, return_when)
# --> 305 waiter.event.wait(timeout)
#     306 for f in fs:
#     307     with f._condition:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
def add_line_numbers(input_file, output_file):
    with open(input_file, 'r') as f_in, open(output_file, 'w') as f_out:
        line_number = 1
        for line in f_in:
            f_out.write(f"{line_number}: {line}")
            line_number += 1

input_file = "websocket.py"
output_file = "output.txt"
h = add_line_numbers(input_file, output_file)
